# %%
import tensorflow as tf
import os
import cv2
import imghdr
import numpy as np
import matplotlib.pyplot as plt
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense , Flatten , Dropout, BatchNormalization
from tensorflow.keras.models import load_model
# Out:
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_37648\3448478996.py:4: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
data_dir = 'datasets'

# %%
images_exts = ['jpeg', 'jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir):
    print(image_class)
    for image in os.listdir(os.path.join(data_dir , image_class)):
        image_path = os.path.join(data_dir , image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in images_exts:
                print(f"{image} doesnot exits in the extension")
                os.remove(image_path)
        except Exception as e:
            print(f"Issue with the image {image}")
# Out:
# Beagle
# German_Shepherd
# Golden_Retriever
# Siberian_Husky

# %%
for image_class in os.listdir(data_dir):
    print(image_class)
# Out:
# Beagle
# German_Shepherd
# Golden_Retriever
# Siberian_Husky

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir , image_class)):
        print(image)
# Out:
# 00xp-beagles-AP-facebookJumbo-v2.jpg
# 2-Jahre-Beagle-768x512.jpg
# 4195-wMr6JS._SL500_.jpg
# 47e924f8d028974fa04275be6b8f185f.jpg
# 61.-Beagle.jpg
# 640px-Beagle_Upsy.jpg
# 67e6a3f1bf14516c30d2cdad0042e993.jpg
# 7dec9387a32071dbc7a3bcffdc08de89Y29udGVudHNlYXJjaGFwaSwxNjkyODkzNDA2-2.73426158.jpg
# 800px-Beagle_harrier.JPG.jpg
# a8b50632a4f324c88fa11e310b027b1d.png
# adorable-beagle-puppy-solo-portrait_53876-73998.jpg
# Are-Beagles-Good-Dogs.jpg
# Basset-Hound-vs-Beagle-1-.jpg
# beagle-1.jpg
# beagle-12.jpg
# beagle-13.jpg
# Beagle-2-1-1024x768.jpeg
# beagle-2_custom-01105a795e7709dcb99ee953d438ef5ca4781622.jpg
# beagle-5375285_1280.jpg
# Beagle-breed-guide-1.jpg
# beagle-card-large.jpg
# Beagle-Dog-Breed-Image-1024x722.jpg
# beagle-dog-breed-of-the-month-1619614746.jpg
# beagle-dog-sitting-with-white-background_53876-30186.jpg
# beagle-dog.jpg
# Beagle-e1587511922360.jpg
# Beagle-head-portrait-in-a-field-in-early-morning-500x486.jpg
# beagle-head.png
# beagle-hero-image-for-breed-page.jpg
# Beagle-hound-dog-puppy.jpg
# beagle-hound-dog.jpg
# beagle-hund.jpg
# beagle-outdoors-gallery-8-min.jpg
# beagle-pup.jpg
# Beagle-puppy-standing-in-the-grass-1.jpeg
# Beagle-Puppy.jpg
# Beagle-scaled.jpeg
# Beagle-standing-in-a-frosty-field-on-a-cold-morning.jpg
# Beagle-Welpe.jpg
# beagle-with-epilepsy-scaled.jpg
# beagle.jpg
# Beagle.png
# beagle2.png
# beagle3.jpg
# beagle4.jpeg
# beagle5.jpg
# BeagleBayleePurebredDogs8Months1.jpg
# Beagles-pets.jpg
# Beagles-standing-in-a-frosty-field-on-a-cold-morning.jpg
# beagle_340_0_orig.jpg
# Beagle_600.jpg
# Beagle_Bloodhound_mix_101_pride_and_groom_1600x.jpg
# Beagle_Featured-Image-1024x615.jpg
# blog-breed-beagle_2.max-400x400.format-jpeg.jpg
# Blue-Tick-beagle3-1024x612.jpg
# siberian-husky-291721_1920-e1670370554151-1200x675.jpg
# siberian-husky-4735878_1920.jpg
# siberian-husky-6554346_960_720.jpg
# siberian-husky-ap-1d3r48-645-x-380.jpg
# Siberian-Husky-courtesy-Eileen-M.-Gacke-2.jpg
# siberian-husky-dog-breed-info.jpeg
# siberian-husky-dog-cute-wolf-winter-forest-snow-closeup_112397-31.jpg
# siberian-husky-dog-cute-wolf-winter-forest-snow_112397-208.jpg
# siberian-husky-dog-snow-winter-portrait-siberian-husky-dog-with-blue-eyes_112397-942.jpg
# Siberian-Husky-dog.jpg
# siberian-husky-in-the-snow.jpg
# Siberian-Husky-Puppies-DeviantArt-Hyper-Realistic-Dark-Illustration-54711303-1.png
# siberian-husky-red-male-outdoors-260nw-2380863487.jpg
# Siberian-Husky-standing-in-profile-outdoors-in-the-winter.jpeg
# Siberian-Husky-standing-outdoors-in-the-winter.jpg
# siberian-husky-winter.jpg
# siberian-husky_1200x1200.jpg
# Siberian-Husky_Featured.jpg
# Siberian-Husky_FeaturedImage-1024x615.jpg
# Siberian20Husky1.jpg
# SiberianHuskyPurebredDogAce2YearsOld.jpg
# Siberian_Husky_resized-modified_1024x1024.png
# simon-rae-jY_2XG-6HU0-unsplash-1024x682.jpg
# Simply20gorgeous20dogs.png
# thousands-of-years-of-the-siberian-husky.png
# Two-Siberian-Husky-puppies.jpg
# vital-stats_husky.png
# When-Do-Siberian-Huskies-Stop-Growing.jpg
# wolf-dog-breeds-siberian-husky-1570411330.jpg

# %%
data = tf.keras.utils.image_dataset_from_directory('datasets')
# Out:
# Found 477 files belonging to 4 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
len(batch)
# Out:
# 2

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
fig, ax = plt.subplots(ncols=5 , figsize=(20,20))
for idx, img in enumerate(batch[0][:5]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# Beagle = 0
# GermanShepherd = 1
# GoldenRetriever = 2
# Husky = 3

# %%
data = data.map(lambda x,y : (x/255, y))

# %%
data.as_numpy_iterator().next()[0].min()
# Out:
# 0.0

# %%
fig, ax = plt.subplots(ncols=4 , figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
len(data)
# Out:
# 15

# %%
train_size = int(len(data)*0.6)
val_size = int(len(data)*0.2)
test_size = int(len(data)*0.2)

# %%
train_size + val_size + test_size
# Out:
# 15

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
model = Sequential()

model.add(Conv2D(16, (3,3), activation='relu', input_shape = (256, 256, 3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 256)               14745856
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 14770468 (56.34 MB)
# Trainable params: 14770468 (56.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
logdir = 'logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=25, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/25
# 9/9 [==============================] - 13s 1s/step - loss: 1.9881 - accuracy: 0.2708 - val_loss: 1.3622 - val_accuracy: 0.2396
# Epoch 2/25
# 9/9 [==============================] - 11s 1s/step - loss: 1.3414 - accuracy: 0.3438 - val_loss: 1.3055 - val_accuracy: 0.3542
# Epoch 3/25
# 9/9 [==============================] - 11s 1s/step - loss: 1.2302 - accuracy: 0.4722 - val_loss: 1.0238 - val_accuracy: 0.6875
# Epoch 4/25
# 9/9 [==============================] - 15s 2s/step - loss: 1.0283 - accuracy: 0.6042 - val_loss: 0.7866 - val_accuracy: 0.7604
# Epoch 5/25
# 9/9 [==============================] - 15s 1s/step - loss: 0.7942 - accuracy: 0.7153 - val_loss: 0.5099 - val_accuracy: 0.8958
# Epoch 6/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.5761 - accuracy: 0.8299 - val_loss: 0.3600 - val_accuracy: 0.9062
# Epoch 7/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.4895 - accuracy: 0.8299 - val_loss: 0.2957 - val_accuracy: 0.9062
# Epoch 8/25
# 9/9 [==============================] - 14s 1s/step - loss: 0.4237 - accuracy: 0.8611 - val_loss: 0.3348 - val_accuracy: 0.8958
# Epoch 9/25
# 9/9 [==============================] - 14s 1s/step - loss: 0.2816 - accuracy: 0.9271 - val_loss: 0.2063 - val_accuracy: 0.9167
# Epoch 10/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.1550 - accuracy: 0.9410 - val_loss: 0.1291 - val_accuracy: 0.9583
# Epoch 11/25
# 9/9 [==============================] - 12s 1s/step - loss: 0.1240 - accuracy: 0.9653 - val_loss: 0.0924 - val_accuracy: 0.9792
# Epoch 12/25
# 9/9 [==============================] - 12s 1s/step - loss: 0.0696 - accuracy: 0.9861 - val_loss: 0.1120 - val_accuracy: 0.9583
# Epoch 13/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.0909 - accuracy: 0.9722 - val_loss: 0.0376 - val_accuracy: 0.9896
# Epoch 14/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.0784 - accuracy: 0.9826 - val_loss: 0.0388 - val_accuracy: 0.9896
# Epoch 15/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.0764 - accuracy: 0.9792 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 16/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.0597 - accuracy: 0.9757 - val_loss: 0.0826 - val_accuracy: 0.9688
# Epoch 17/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.0971 - accuracy: 0.9688 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 18/25
# 9/9 [==============================] - 14s 1s/step - loss: 0.0542 - accuracy: 0.9826 - val_loss: 0.0302 - val_accuracy: 0.9896
# Epoch 19/25
# 9/9 [==============================] - 17s 2s/step - loss: 0.0509 - accuracy: 0.9861 - val_loss: 0.0445 - val_accuracy: 0.9896
# Epoch 20/25
# 9/9 [==============================] - 22s 2s/step - loss: 0.0410 - accuracy: 0.9896 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 21/25
# 9/9 [==============================] - 26s 3s/step - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 22/25
# 9/9 [==============================] - 15s 1s/step - loss: 0.0279 - accuracy: 0.9965 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 23/25
# 9/9 [==============================] - 24s 2s/step - loss: 0.0144 - accuracy: 0.9965 - val_loss: 0.0171 - val_accuracy: 0.9896
# Epoch 24/25
# 9/9 [==============================] - 22s 2s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9896
# Epoch 25/25
# 9/9 [==============================] - 25s 2s/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.0046 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
plt.suptitle('Loss', fontsize=20)
plt.legend()
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
plt.suptitle('Loss', fontsize=20)
plt.legend()
plt.show()

# %%
def predict(img_path):
    img = cv2.imread(img_path)
    resize = tf.image.resize(img, (256,256))
    yhat = model.predict(np.expand_dims(resize/255, 0))
    max_index = np.argmax(yhat[0])

    if max_index == 0:
        print("beagle")
    elif max_index == 1:
        print("German Shepherd")
    elif max_index ==  2:
        print("GoldenRetriever")
    else:
        print("Husky")

# %%
predict('beagle.jpg')
# Out:
# 1/1 [==============================] - 0s 210ms/step
# beagle

# %%
model.save(os.path.join('models', 'golden_trio.h5'))
# Out:
# c:\Users\Shivam\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
